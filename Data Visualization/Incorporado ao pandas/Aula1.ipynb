# %%
import numpy as np
import pandas as pd
import matplotlib as plt
plt.style.use('bmh')

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv("df1", index_col=0)
df2 = pd.read_csv("df2")

# %%
df1['A'].hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index, y='B')

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3))

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3), lw=1)

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='Oranges')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*30)
# Out:
# /home/claesia/anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.box()

# %%
df = pd.DataFrame(np.random.rand(1000,2), columns=['A', 'B'])

# %%
df.plot.hexbin(x='A', y='B', gridsize=20, cmap='inferno')

# %%
df2['a'].plot.kde()

# %%
df2.plot.kde()
